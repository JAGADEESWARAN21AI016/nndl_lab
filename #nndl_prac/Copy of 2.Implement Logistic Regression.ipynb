# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam
# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Normalize pixel values to be between 0 and 1
x_train, x_test = x_train / 255.0, x_test / 255.0
# Flatten the images to 1D arrays
x_train = x_train.reshape(-1, 28 * 28)
x_test = x_test.reshape(-1, 28 * 28)
# Create a binary classification task (odd or even)
y_train = (y_train % 2 == 0).astype(np.float32)
y_test = (y_test % 2 == 0).astype(np.float32)
# Build a Logistic Regression model
model = Sequential([
Flatten(input_shape=(28 * 28,)), # Adjusted input shape
Dense(1, activation='sigmoid')
])
# Compile the model
model.compile(optimizer=Adam(), loss=BinaryCrossentropy(), metrics=['accuracy'])
# Train the model
model.fit(x_train, y_train, epochs=5, batch_size=32, validation_data=(x_test, y_test))
# Evaluate the model
loss, accuracy = model.evaluate(x_test, y_test)
print('Test accuracy:', accuracy)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step
# Epoch 1/5
# 1875/1875 [==============================] - 11s 3ms/step - loss: 0.3232 - accuracy: 0.8660 - val_loss: 0.2758 - val_accuracy: 0.8898
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2711 - accuracy: 0.8913 - val_loss: 0.2631 - val_accuracy: 0.8962
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2625 - accuracy: 0.8960 - val_loss: 0.2619 - val_accuracy: 0.8990
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2590 - accuracy: 0.8979 - val_loss: 0.2585 - val_accuracy: 0.8975
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2570 - accuracy: 0.8990 - val_loss: 0.2606 - val_accuracy: 0.9003
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2606 - accuracy: 0.9003
# Test accuracy: 0.9003000259399414
