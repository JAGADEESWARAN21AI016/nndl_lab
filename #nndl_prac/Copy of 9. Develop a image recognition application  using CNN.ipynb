# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt

# Load and preprocess the CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0  # Normalize pixel values to be between 0 and 1
train_labels, test_labels = to_categorical(train_labels), to_categorical(test_labels)  # One-hot encode labels

# Build a CNN model
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(train_images, train_labels, epochs=10, validation_data=(test_images, test_labels))

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_acc}')

# Make predictions
predictions = model.predict(test_images)

# Display some random test images with their predicted captions
num_images_to_display = 5
random_indices = np.random.choice(len(test_images), num_images_to_display, replace=False)

for i in random_indices:
    plt.figure()
    plt.imshow(test_images[i])
    plt.title(f'Actual: {np.argmax(test_labels[i])}, Predicted: {np.argmax(predictions[i])}')
    plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step
# Epoch 1/10
# 1563/1563 [==============================] - 18s 6ms/step - loss: 1.4845 - accuracy: 0.4584 - val_loss: 1.2146 - val_accuracy: 0.5638
# Epoch 2/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.1022 - accuracy: 0.6124 - val_loss: 1.0206 - val_accuracy: 0.6389
# Epoch 3/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.9445 - accuracy: 0.6686 - val_loss: 0.9243 - val_accuracy: 0.6770
# Epoch 4/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.8432 - accuracy: 0.7045 - val_loss: 0.8815 - val_accuracy: 0.6952
# Epoch 5/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.7660 - accuracy: 0.7327 - val_loss: 0.8473 - val_accuracy: 0.7103
# Epoch 6/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.7004 - accuracy: 0.7540 - val_loss: 0.8470 - val_accuracy: 0.7160
# Epoch 7/10
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.6454 - accuracy: 0.7723 - val_loss: 0.8324 - val_accuracy: 0.7201
# Epoch 8/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.6001 - accuracy: 0.7888 - val_loss: 0.8390 - val_accuracy: 0.7217
# Epoch 9/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.5516 - accuracy: 0.8059 - val_loss: 0.8623 - val_accuracy: 0.7212
# Epoch 10/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5089 - accuracy: 0.8182 - val_loss: 0.9181 - val_accuracy: 0.7093
# 313/313 [==============================] - 1s 3ms/step - loss: 0.9181 - accuracy: 0.7093
# Test accuracy: 0.7092999815940857
# 313/313 [==============================] - 1s 2ms/step

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt

# Load and preprocess the CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0  # Normalize pixel values to be between 0 and 1
train_labels, test_labels = to_categorical(train_labels), to_categorical(test_labels)  # One-hot encode labels

# Define CIFAR-10 class names
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Build a CNN model
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(train_images, train_labels, epochs=10, validation_data=(test_images, test_labels))

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_acc}')

# Make predictions
predictions = model.predict(test_images)

# Display some random test images with their actual, predicted labels, and class names
num_images_to_display = 5
random_indices = np.random.choice(len(test_images), num_images_to_display, replace=False)

for i in random_indices:
    plt.figure()
    plt.imshow(test_images[i])
    actual_class = class_names[np.argmax(test_labels[i])]
    predicted_class = class_names[np.argmax(predictions[i])]
    plt.title(f'Actual: {actual_class}, Predicted: {predicted_class}')
    plt.show()
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 11s 6ms/step - loss: 1.5244 - accuracy: 0.4424 - val_loss: 1.2598 - val_accuracy: 0.5482
# Epoch 2/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.1566 - accuracy: 0.5880 - val_loss: 1.0517 - val_accuracy: 0.6315
# Epoch 3/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.9885 - accuracy: 0.6509 - val_loss: 0.9962 - val_accuracy: 0.6509
# Epoch 4/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.8841 - accuracy: 0.6899 - val_loss: 0.9377 - val_accuracy: 0.6677
# Epoch 5/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.8113 - accuracy: 0.7163 - val_loss: 0.8956 - val_accuracy: 0.6947
# Epoch 6/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7355 - accuracy: 0.7425 - val_loss: 0.8785 - val_accuracy: 0.7042
# Epoch 7/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.6829 - accuracy: 0.7614 - val_loss: 0.8724 - val_accuracy: 0.7019
# Epoch 8/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.6301 - accuracy: 0.7776 - val_loss: 0.8446 - val_accuracy: 0.7151
# Epoch 9/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5872 - accuracy: 0.7933 - val_loss: 0.8643 - val_accuracy: 0.7160
# Epoch 10/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.5435 - accuracy: 0.8102 - val_loss: 0.8722 - val_accuracy: 0.7199
# 313/313 [==============================] - 1s 3ms/step - loss: 0.8722 - accuracy: 0.7199
# Test accuracy: 0.7199000120162964
# 313/313 [==============================] - 1s 2ms/step

# %%
for i in random_indices:
    plt.figure(figsize=(1, 1))
    plt.imshow(test_images[i])
    actual_class = class_names[np.argmax(test_labels[i])]
    predicted_class = class_names[np.argmax(predictions[i])]
    plt.title(f'Actual: {actual_class}, Predicted: {predicted_class}')
    plt.show()
