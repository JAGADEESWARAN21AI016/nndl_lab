# %%
#Import necessary libraries:
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical
#Load and preprocess the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train / 255.0 # Normalize pixel values to range [0, 1]
x_test = x_test / 255.0
y_train = to_categorical(y_train, num_classes=10) # One-hot encode labels
y_test = to_categorical(y_test, num_classes=10)
#Build the multi-layer neural network:
model = Sequential()
model.add(Flatten(input_shape=(28, 28))) # Flatten 28x28 images to a 1D array
model.add(Dense(128, activation='relu')) # Hidden layer with 128 neurons and ReLU activation
model.add(Dense(10, activation='softmax')) # Output layer with 10 neurons (for 10 classes) and softmax activation
#Compile the model:
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#Train the model:
model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=5, batch_size=32)
#Evaluate the model:
loss, accuracy = model.evaluate(x_test, y_test)
print('Test accuracy:', accuracy)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 12s 4ms/step - loss: 0.2576 - accuracy: 0.9262 - val_loss: 0.1332 - val_accuracy: 0.9602
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1141 - accuracy: 0.9660 - val_loss: 0.0983 - val_accuracy: 0.9711
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0793 - accuracy: 0.9763 - val_loss: 0.0946 - val_accuracy: 0.9701
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0578 - accuracy: 0.9820 - val_loss: 0.0823 - val_accuracy: 0.9742
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0454 - accuracy: 0.9859 - val_loss: 0.0795 - val_accuracy: 0.9755
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0795 - accuracy: 0.9755
# Test accuracy: 0.9754999876022339
